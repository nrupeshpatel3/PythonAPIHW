# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
from pprint import pprint


# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Create url
url="api.openweathermap.org/data/2.5/weather?"

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
api_key
# Out:
# 'f9d646397a4637065a035d08e4b6696a'

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 638

# %%
#Creating Cities list from city 
cities_df=pd.DataFrame(cities)
cities_name_df=cities_df.rename(columns={0:"city"})
cities_name= cities_name_df["city"].tolist()
len(cities_name)
# Out:
# 638

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key 

# List of city data
city_data = []

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "&q=" + city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out the max temp, humidity, and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
# Out:
# Processing Record 1 of Set 1 | saskylakh
# Processing Record 2 of Set 1 | itarema
# Processing Record 3 of Set 1 | faanui
# Processing Record 4 of Set 1 | antofagasta
# Processing Record 5 of Set 1 | tiksi
# Processing Record 6 of Set 1 | thompson
# Processing Record 7 of Set 1 | hobart
# Processing Record 8 of Set 1 | rikitea
# Processing Record 9 of Set 1 | ribeira grande
# Processing Record 10 of Set 1 | saint-philippe
# Processing Record 11 of Set 1 | salinas
# Processing Record 12 of Set 1 | kapaa
# Processing Record 13 of Set 1 | bibiani
# Processing Record 14 of Set 1 | fairbanks
# Processing Record 15 of Set 1 | puerto ayora
# Processing Record 16 of Set 1 | bluff
# Processing Record 17 of Set 1 | iqaluit
# Processing Record 18 of Set 1 | chokurdakh
# Processing Record 19 of Set 1 | chuy
# Processing Record 20 of Set 1 | poso
# Processing Record 21 of Set 1 | whitecourt
# Processing Record 22 of Set 1 | saiha
# Processing Record 23 of Set 1 | umm lajj
# Processing Record 24 of Set 1 | punta arenas
# Processing Record 25 of Set 1 | asfi
# City not found. Skipping...
# Processing Record 26 of Set 1 | dingtao
# Processing Record 27 of Set 1 | vilhena
# Processing Record 28 of Set 1 | castro
# Processing Record 29 of Set 1 | bela
# Processing Record 30 of Set 1 | sioux lookout
# Processing Record 31 of Set 1 | novouzensk
# Processing Record 32 of Set 1 | san rafael
# Processing Record 33 of Set 1 | talnakh
# Processing Record 34 of Set 1 | cabedelo
# Processing Record 35 of Set 1 | benguela
# Processing Record 36 of Set 1 | carnarvon
# Processing Record 37 of Set 1 | ust-kuyga
# Processing Record 38 of Set 1 | cape town
# Processing Record 39 of Set 1 | busselton
# Processing Record 40 of Set 1 | adre
# Processing Record 41 of Set 1 | ushuaia
# Processing Record 42 of Set 1 | cherskiy
# Processing Record 43 of Set 1 | komyshuvakha
# Processing Record 44 of Set 1 | mataura
# Processing Record 45 of Set 1 | east london
# Processing Record 46 of Set 1 | bhilwara
# Processing Record 47 of Set 1 | pringsewu
# Processing Record 48 of Set 1 | port elizabeth
# Processing Record 49 of Set 1 | roald
# Processing Record 50 of Set 1 | meulaboh
# Processing Record 0 of Set 2 | vaini
# Processing Record 1 of Set 2 | fortuna
# Processing Record 2 of Set 2 | kungurtug
# Processing Record 3 of Set 2 | hermanus
# Processing Record 4 of Set 2 | goure
# Processing Record 5 of Set 2 | olafsvik
# City not found. Skipping...
# Processing Record 6 of Set 2 | namibe
# Processing Record 7 of Set 2 | butaritari
# Processing Record 8 of Set 2 | nanortalik
# Processing Record 9 of Set 2 | mersing
# Processing Record 10 of Set 2 | bilma
# Processing Record 11 of Set 2 | barrow
# Processing Record 12 of Set 2 | qaanaaq
# Processing Record 13 of Set 2 | laguna
# Processing Record 14 of Set 2 | tasiilaq
# Processing Record 15 of Set 2 | burnie
# Processing Record 16 of Set 2 | khatanga
# Processing Record 17 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 18 of Set 2 | tevaitoa
# Processing Record 19 of Set 2 | mareeba
# Processing Record 20 of Set 2 | abha
# Processing Record 21 of Set 2 | muros
# Processing Record 22 of Set 2 | yumen
# Processing Record 23 of Set 2 | bredasdorp
# Processing Record 24 of Set 2 | kisangani
# Processing Record 25 of Set 2 | fomboni
# Processing Record 26 of Set 2 | atuona
# Processing Record 27 of Set 2 | kasangulu
# Processing Record 28 of Set 2 | georgetown
# Processing Record 29 of Set 2 | avarua
# Processing Record 30 of Set 2 | vila velha
# Processing Record 31 of Set 2 | betafo
# Processing Record 32 of Set 2 | sabang
# Processing Record 33 of Set 2 | hamilton
# Processing Record 34 of Set 2 | souillac
# Processing Record 35 of Set 2 | lujan
# Processing Record 36 of Set 2 | uaua
# Processing Record 37 of Set 2 | semey
# Processing Record 38 of Set 2 | albany
# Processing Record 39 of Set 2 | tsumeb
# Processing Record 40 of Set 2 | kuala terengganu
# Processing Record 41 of Set 2 | hilo
# Processing Record 42 of Set 2 | nikolskoye
# Processing Record 43 of Set 2 | ola
# Processing Record 44 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 45 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 46 of Set 2 | college
# Processing Record 47 of Set 2 | victoria
# Processing Record 48 of Set 2 | ilulissat
# Processing Record 49 of Set 2 | mata de sao joao
# Processing Record 0 of Set 3 | sokolo
# Processing Record 1 of Set 3 | mildura
# Processing Record 2 of Set 3 | puerto del rosario
# Processing Record 3 of Set 3 | new norfolk
# Processing Record 4 of Set 3 | fairmont
# Processing Record 5 of Set 3 | palmer
# Processing Record 6 of Set 3 | nguruka
# Processing Record 7 of Set 3 | ryotsu
# Processing Record 8 of Set 3 | margate
# Processing Record 9 of Set 3 | lukovetskiy
# Processing Record 10 of Set 3 | monrovia
# Processing Record 11 of Set 3 | kaitangata
# Processing Record 12 of Set 3 | qeshm
# Processing Record 13 of Set 3 | bethel
# Processing Record 14 of Set 3 | severnyy
# City not found. Skipping...
# Processing Record 15 of Set 3 | mar del plata
# Processing Record 16 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 17 of Set 3 | provideniya
# Processing Record 18 of Set 3 | quillota
# Processing Record 19 of Set 3 | kota kinabalu
# Processing Record 20 of Set 3 | bengkulu
# City not found. Skipping...
# Processing Record 21 of Set 3 | honningsvag
# Processing Record 22 of Set 3 | natal
# Processing Record 23 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 24 of Set 3 | zhangjiakou
# Processing Record 25 of Set 3 | aklavik
# Processing Record 26 of Set 3 | gamba
# Processing Record 27 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 28 of Set 3 | ijaki
# City not found. Skipping...
# Processing Record 29 of Set 3 | alice springs
# Processing Record 30 of Set 3 | lebu
# Processing Record 31 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 32 of Set 3 | changping
# Processing Record 33 of Set 3 | paysandu
# Processing Record 34 of Set 3 | clyde river
# Processing Record 35 of Set 3 | srednekolymsk
# Processing Record 36 of Set 3 | broken hill
# Processing Record 37 of Set 3 | airai
# Processing Record 38 of Set 3 | bourail
# Processing Record 39 of Set 3 | cabo san lucas
# Processing Record 40 of Set 3 | ozinki
# Processing Record 41 of Set 3 | puerto escondido
# Processing Record 42 of Set 3 | pathalgaon
# Processing Record 43 of Set 3 | vakhrushev
# Processing Record 44 of Set 3 | bubaque
# Processing Record 45 of Set 3 | port-gentil
# Processing Record 46 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 47 of Set 3 | chabahar
# Processing Record 48 of Set 3 | saint george
# Processing Record 49 of Set 3 | halalo
# City not found. Skipping...
# Processing Record 0 of Set 4 | louisbourg
# City not found. Skipping...
# Processing Record 1 of Set 4 | hofn
# Processing Record 2 of Set 4 | birjand
# Processing Record 3 of Set 4 | ponta do sol
# Processing Record 4 of Set 4 | demyanovo
# Processing Record 5 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 6 of Set 4 | najran
# Processing Record 7 of Set 4 | hami
# Processing Record 8 of Set 4 | tual
# Processing Record 9 of Set 4 | vestmannaeyjar
# Processing Record 10 of Set 4 | broome
# Processing Record 11 of Set 4 | vilyuysk
# Processing Record 12 of Set 4 | ngaoundere
# Processing Record 13 of Set 4 | kamenka
# Processing Record 14 of Set 4 | marsh harbour
# Processing Record 15 of Set 4 | padang
# Processing Record 16 of Set 4 | jamestown
# Processing Record 17 of Set 4 | yellowknife
# Processing Record 18 of Set 4 | bela vista do paraiso
# Processing Record 19 of Set 4 | port lavaca
# Processing Record 20 of Set 4 | coihaique
# Processing Record 21 of Set 4 | erzin
# Processing Record 22 of Set 4 | lagoa
# Processing Record 23 of Set 4 | hunza
# City not found. Skipping...
# Processing Record 24 of Set 4 | ndele
# City not found. Skipping...
# Processing Record 25 of Set 4 | turmalina
# Processing Record 26 of Set 4 | olinda
# Processing Record 27 of Set 4 | guerrero negro
# Processing Record 28 of Set 4 | sidi qasim
# City not found. Skipping...
# Processing Record 29 of Set 4 | pisco
# Processing Record 30 of Set 4 | sassandra
# Processing Record 31 of Set 4 | san patricio
# Processing Record 32 of Set 4 | severo-kurilsk
# Processing Record 33 of Set 4 | dwarka
# Processing Record 34 of Set 4 | whitehorse
# Processing Record 35 of Set 4 | dzhusaly
# City not found. Skipping...
# Processing Record 36 of Set 4 | trairi
# Processing Record 37 of Set 4 | bayan
# Processing Record 38 of Set 4 | anamur
# Processing Record 39 of Set 4 | ocos
# Processing Record 40 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 41 of Set 4 | port hardy
# Processing Record 42 of Set 4 | wamba
# Processing Record 43 of Set 4 | mahebourg
# Processing Record 44 of Set 4 | bathsheba
# Processing Record 45 of Set 4 | gonbad-e qabus
# Processing Record 46 of Set 4 | yulara
# Processing Record 47 of Set 4 | el faiyum
# City not found. Skipping...
# Processing Record 48 of Set 4 | tacna
# Processing Record 49 of Set 4 | ca mau
# Processing Record 0 of Set 5 | saldanha
# Processing Record 1 of Set 5 | vostok
# Processing Record 2 of Set 5 | kropotkin
# Processing Record 3 of Set 5 | aitape
# Processing Record 4 of Set 5 | sibolga
# Processing Record 5 of Set 5 | rio grande
# Processing Record 6 of Set 5 | cockburn town
# Processing Record 7 of Set 5 | williams lake
# Processing Record 8 of Set 5 | ambositra
# Processing Record 9 of Set 5 | bodden town
# Processing Record 10 of Set 5 | pacific grove
# Processing Record 11 of Set 5 | jamame
# Processing Record 12 of Set 5 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 13 of Set 5 | rostaq
# City not found. Skipping...
# Processing Record 14 of Set 5 | wuwei
# Processing Record 15 of Set 5 | brigantine
# Processing Record 16 of Set 5 | pevek
# Processing Record 17 of Set 5 | huarmey
# Processing Record 18 of Set 5 | tvoroyri
# Processing Record 19 of Set 5 | benicarlo
# Processing Record 20 of Set 5 | quang ngai
# Processing Record 21 of Set 5 | zonguldak
# Processing Record 22 of Set 5 | zhangye
# Processing Record 23 of Set 5 | san quintin
# Processing Record 24 of Set 5 | portland
# Processing Record 25 of Set 5 | longyearbyen
# Processing Record 26 of Set 5 | te anau
# Processing Record 27 of Set 5 | rungata
# City not found. Skipping...
# Processing Record 28 of Set 5 | norman wells
# Processing Record 29 of Set 5 | nelson bay
# Processing Record 30 of Set 5 | lavrentiya
# Processing Record 31 of Set 5 | khanpur
# Processing Record 32 of Set 5 | arraial do cabo
# Processing Record 33 of Set 5 | yar-sale
# Processing Record 34 of Set 5 | the valley
# Processing Record 35 of Set 5 | santiago
# Processing Record 36 of Set 5 | vidim
# Processing Record 37 of Set 5 | lompoc
# Processing Record 38 of Set 5 | ibia
# Processing Record 39 of Set 5 | bambous virieux
# Processing Record 40 of Set 5 | tura
# Processing Record 41 of Set 5 | mangrol
# Processing Record 42 of Set 5 | sayyan
# Processing Record 43 of Set 5 | uniao da victoria
# City not found. Skipping...
# Processing Record 44 of Set 5 | xiongyue
# Processing Record 45 of Set 5 | itabira
# Processing Record 46 of Set 5 | luderitz
# Processing Record 47 of Set 5 | rock hill
# Processing Record 48 of Set 5 | saint-pierre
# Processing Record 49 of Set 5 | dunedin
# Processing Record 0 of Set 6 | ozark
# Processing Record 1 of Set 6 | filadelfia
# Processing Record 2 of Set 6 | faya
# Processing Record 3 of Set 6 | talwandi bhai
# Processing Record 4 of Set 6 | nong khai
# Processing Record 5 of Set 6 | nishihara
# Processing Record 6 of Set 6 | mazara del vallo
# Processing Record 7 of Set 6 | chuguyevka
# Processing Record 8 of Set 6 | maningrida
# Processing Record 9 of Set 6 | tabuk
# Processing Record 10 of Set 6 | pereslavl-zalesskiy
# Processing Record 11 of Set 6 | sangar
# Processing Record 12 of Set 6 | north myrtle beach
# Processing Record 13 of Set 6 | verkhoyansk
# Processing Record 14 of Set 6 | fukue
# Processing Record 15 of Set 6 | sao felix do xingu
# Processing Record 16 of Set 6 | camana
# City not found. Skipping...
# Processing Record 17 of Set 6 | old saybrook
# Processing Record 18 of Set 6 | ventspils
# Processing Record 19 of Set 6 | zhigansk
# Processing Record 20 of Set 6 | kodiak
# Processing Record 21 of Set 6 | kununurra
# Processing Record 22 of Set 6 | banjar
# Processing Record 23 of Set 6 | tosya
# Processing Record 24 of Set 6 | buala
# Processing Record 25 of Set 6 | boden
# Processing Record 26 of Set 6 | wattegama
# Processing Record 27 of Set 6 | evensk
# Processing Record 28 of Set 6 | aykhal
# Processing Record 29 of Set 6 | saint john
# Processing Record 30 of Set 6 | kokomo
# Processing Record 31 of Set 6 | auki
# Processing Record 32 of Set 6 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 33 of Set 6 | lake havasu city
# Processing Record 34 of Set 6 | basco
# Processing Record 35 of Set 6 | evans
# Processing Record 36 of Set 6 | omboue
# Processing Record 37 of Set 6 | tatarsk
# Processing Record 38 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 39 of Set 6 | pallasovka
# Processing Record 40 of Set 6 | narsaq
# Processing Record 41 of Set 6 | tromso
# Processing Record 42 of Set 6 | derzhavinsk
# Processing Record 43 of Set 6 | sulangan
# Processing Record 44 of Set 6 | constitucion
# Processing Record 45 of Set 6 | campbell river
# Processing Record 46 of Set 6 | chicama
# Processing Record 47 of Set 6 | sao filipe
# Processing Record 48 of Set 6 | maniitsoq
# Processing Record 49 of Set 6 | hithadhoo
# Processing Record 0 of Set 7 | nanchang
# Processing Record 1 of Set 7 | puerto colombia
# Processing Record 2 of Set 7 | leh
# Processing Record 3 of Set 7 | yining
# Processing Record 4 of Set 7 | nizwa
# Processing Record 5 of Set 7 | tocopilla
# Processing Record 6 of Set 7 | terrace bay
# Processing Record 7 of Set 7 | north platte
# Processing Record 8 of Set 7 | hasaki
# Processing Record 9 of Set 7 | port alfred
# Processing Record 10 of Set 7 | dana point
# Processing Record 11 of Set 7 | warri
# Processing Record 12 of Set 7 | barabai
# Processing Record 13 of Set 7 | zastron
# Processing Record 14 of Set 7 | soldotna
# Processing Record 15 of Set 7 | jining
# Processing Record 16 of Set 7 | bhawana
# Processing Record 17 of Set 7 | igarka
# Processing Record 18 of Set 7 | alcacer do sal
# Processing Record 19 of Set 7 | chimbote
# Processing Record 20 of Set 7 | samana
# Processing Record 21 of Set 7 | belushya guba
# City not found. Skipping...
# Processing Record 22 of Set 7 | itaituba
# Processing Record 23 of Set 7 | ponta delgada
# Processing Record 24 of Set 7 | caravelas
# Processing Record 25 of Set 7 | lazaro cardenas
# Processing Record 26 of Set 7 | pahrump
# Processing Record 27 of Set 7 | sao joao da barra
# Processing Record 28 of Set 7 | krasnogorsk
# Processing Record 29 of Set 7 | nara
# Processing Record 30 of Set 7 | urrao
# Processing Record 31 of Set 7 | bardiyah
# City not found. Skipping...
# Processing Record 32 of Set 7 | agotnes
# Processing Record 33 of Set 7 | griffith
# Processing Record 34 of Set 7 | beringovskiy
# Processing Record 35 of Set 7 | taburi
# City not found. Skipping...
# Processing Record 36 of Set 7 | aloleng
# Processing Record 37 of Set 7 | callaguip
# Processing Record 38 of Set 7 | ugoofaaru
# Processing Record 39 of Set 7 | basoko
# Processing Record 40 of Set 7 | borba
# Processing Record 41 of Set 7 | kyakhta
# Processing Record 42 of Set 7 | nguiu
# City not found. Skipping...
# Processing Record 43 of Set 7 | salinopolis
# Processing Record 44 of Set 7 | vila franca do campo
# Processing Record 45 of Set 7 | yagodnoye
# Processing Record 46 of Set 7 | buchanan
# Processing Record 47 of Set 7 | orumiyeh
# Processing Record 48 of Set 7 | grand-lahou
# Processing Record 49 of Set 7 | obidos
# Processing Record 0 of Set 8 | sharan
# Processing Record 1 of Set 8 | fort nelson
# Processing Record 2 of Set 8 | jiddah
# City not found. Skipping...
# Processing Record 3 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 4 of Set 8 | necochea
# Processing Record 5 of Set 8 | klaksvik
# Processing Record 6 of Set 8 | turinsk
# Processing Record 7 of Set 8 | missungwi
# Processing Record 8 of Set 8 | cooma
# Processing Record 9 of Set 8 | iquitos
# Processing Record 10 of Set 8 | komsomolskiy
# Processing Record 11 of Set 8 | port hawkesbury
# Processing Record 12 of Set 8 | beloha
# Processing Record 13 of Set 8 | vicuna
# City not found. Skipping...
# Processing Record 14 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 15 of Set 8 | tuatapere
# Processing Record 16 of Set 8 | mont-de-marsan
# Processing Record 17 of Set 8 | odweyne
# City not found. Skipping...
# Processing Record 18 of Set 8 | urgut
# Processing Record 19 of Set 8 | dorado
# Processing Record 20 of Set 8 | novobirilyussy
# Processing Record 21 of Set 8 | vanimo
# Processing Record 22 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 23 of Set 8 | tautira
# Processing Record 24 of Set 8 | dhidhdhoo
# Processing Record 25 of Set 8 | balsas
# Processing Record 26 of Set 8 | pimentel
# Processing Record 27 of Set 8 | ano mera
# Processing Record 28 of Set 8 | eyl
# Processing Record 29 of Set 8 | upernavik
# Processing Record 30 of Set 8 | kapitan ramon
# Processing Record 31 of Set 8 | berbera
# City not found. Skipping...
# Processing Record 32 of Set 8 | saint-joseph
# Processing Record 33 of Set 8 | mehamn
# Processing Record 34 of Set 8 | egvekinot
# Processing Record 35 of Set 8 | los banos
# Processing Record 36 of Set 8 | saint-louis
# Processing Record 37 of Set 8 | savannah bight
# Processing Record 38 of Set 8 | barawe
# City not found. Skipping...
# Processing Record 39 of Set 8 | bacolod
# Processing Record 40 of Set 8 | atar
# Processing Record 41 of Set 8 | port blair
# Processing Record 42 of Set 8 | boa vista
# Processing Record 43 of Set 8 | kargat
# Processing Record 44 of Set 8 | orsha
# Processing Record 45 of Set 8 | krasnaya gora
# Processing Record 46 of Set 8 | agua verde
# Processing Record 47 of Set 8 | flinders
# Processing Record 48 of Set 8 | kahului
# Processing Record 49 of Set 8 | naze
# Processing Record 0 of Set 9 | gazanjyk
# Processing Record 1 of Set 9 | veraval
# Processing Record 2 of Set 9 | ust-nera
# Processing Record 3 of Set 9 | koupela
# Processing Record 4 of Set 9 | tipitapa
# Processing Record 5 of Set 9 | praia da vitoria
# Processing Record 6 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 7 of Set 9 | imphal
# Processing Record 8 of Set 9 | plettenberg bay
# Processing Record 9 of Set 9 | bargal
# City not found. Skipping...
# Processing Record 10 of Set 9 | tshela
# Processing Record 11 of Set 9 | kuhestan
# City not found. Skipping...
# Processing Record 12 of Set 9 | kragujevac
# Processing Record 13 of Set 9 | shenjiamen
# Processing Record 14 of Set 9 | nosy varika
# Processing Record 15 of Set 9 | yazoo city
# Processing Record 16 of Set 9 | goderich
# Processing Record 17 of Set 9 | bambanglipuro
# Processing Record 18 of Set 9 | liku
# Processing Record 19 of Set 9 | pandan
# Processing Record 20 of Set 9 | porto velho
# Processing Record 21 of Set 9 | haines junction
# Processing Record 22 of Set 9 | wairoa
# Processing Record 23 of Set 9 | vaitape
# Processing Record 24 of Set 9 | awjilah
# Processing Record 25 of Set 9 | dhemaji
# Processing Record 26 of Set 9 | jitra
# Processing Record 27 of Set 9 | marsaxlokk
# Processing Record 28 of Set 9 | kismayo
# City not found. Skipping...
# Processing Record 29 of Set 9 | constantine
# Processing Record 30 of Set 9 | chernyshevskiy
# Processing Record 31 of Set 9 | pak phanang
# Processing Record 32 of Set 9 | kommunisticheskiy
# Processing Record 33 of Set 9 | bongandanga
# Processing Record 34 of Set 9 | mount gambier
# Processing Record 35 of Set 9 | giyon
# Processing Record 36 of Set 9 | zhangzhou
# Processing Record 37 of Set 9 | ancud
# Processing Record 38 of Set 9 | walvis bay
# Processing Record 39 of Set 9 | syracuse
# Processing Record 40 of Set 9 | ituni
# City not found. Skipping...
# Processing Record 41 of Set 9 | palana
# Processing Record 42 of Set 9 | alyangula
# Processing Record 43 of Set 9 | half moon bay
# Processing Record 44 of Set 9 | villazon
# City not found. Skipping...
# Processing Record 45 of Set 9 | sinegorye
# Processing Record 46 of Set 9 | grand centre
# City not found. Skipping...
# Processing Record 47 of Set 9 | hualmay
# Processing Record 48 of Set 9 | geraldton
# Processing Record 49 of Set 9 | kavaratti
# Processing Record 0 of Set 10 | marawi
# Processing Record 1 of Set 10 | sitka
# Processing Record 2 of Set 10 | parabel
# Processing Record 3 of Set 10 | cayenne
# Processing Record 4 of Set 10 | mount isa
# Processing Record 5 of Set 10 | longjiang
# Processing Record 6 of Set 10 | cap-aux-meules
# Processing Record 7 of Set 10 | mahibadhoo
# Processing Record 8 of Set 10 | stanilesti
# Processing Record 9 of Set 10 | torbay
# Processing Record 10 of Set 10 | banda aceh
# Processing Record 11 of Set 10 | livenka
# Processing Record 12 of Set 10 | port hedland
# Processing Record 13 of Set 10 | inirida
# Processing Record 14 of Set 10 | pemangkat
# City not found. Skipping...
# Processing Record 15 of Set 10 | grand gaube
# Processing Record 16 of Set 10 | tarko-sale
# Processing Record 17 of Set 10 | comodoro rivadavia
# Processing Record 18 of Set 10 | nova olinda do norte
# Processing Record 19 of Set 10 | afonso bezerra
# Processing Record 20 of Set 10 | zamora
# Processing Record 21 of Set 10 | bitlis
# Processing Record 22 of Set 10 | jujuy
# City not found. Skipping...
# Processing Record 23 of Set 10 | afikpo
# Processing Record 24 of Set 10 | juneau
# Processing Record 25 of Set 10 | los llanos de aridane
# Processing Record 26 of Set 10 | kruisfontein
# Processing Record 27 of Set 10 | zhuhai
# Processing Record 28 of Set 10 | brandfort
# Processing Record 29 of Set 10 | dir
# Processing Record 30 of Set 10 | los algarrobos
# Processing Record 31 of Set 10 | dikson
# Processing Record 32 of Set 10 | mugumu
# Processing Record 33 of Set 10 | tecoanapa
# Processing Record 34 of Set 10 | aripuana
# Processing Record 35 of Set 10 | korla
# City not found. Skipping...
# Processing Record 36 of Set 10 | lalganj
# Processing Record 37 of Set 10 | iquique
# Processing Record 38 of Set 10 | kapelle
# Processing Record 39 of Set 10 | tuktoyaktuk
# Processing Record 40 of Set 10 | attawapiskat
# City not found. Skipping...
# Processing Record 41 of Set 10 | khonuu
# City not found. Skipping...
# Processing Record 42 of Set 10 | lebanon
# Processing Record 43 of Set 10 | afrikanda
# Processing Record 44 of Set 10 | rock sound
# Processing Record 45 of Set 10 | norwich
# City not found. Skipping...
# Processing Record 46 of Set 10 | poum
# City not found. Skipping...
# Processing Record 47 of Set 10 | biak
# City not found. Skipping...
# Processing Record 48 of Set 10 | aljezur
# City not found. Skipping...
# Processing Record 49 of Set 10 | develi
# City not found. Skipping...
# Processing Record 0 of Set 11 | takoradi
# City not found. Skipping...
# Processing Record 1 of Set 11 | puerto ayacucho
# City not found. Skipping...
# Processing Record 2 of Set 11 | sambava
# Processing Record 3 of Set 11 | berdigestyakh
# Processing Record 4 of Set 11 | ilam
# Processing Record 5 of Set 11 | oliveira do hospital
# Processing Record 6 of Set 11 | panzhihua
# City not found. Skipping...
# Processing Record 7 of Set 11 | beipiao
# City not found. Skipping...
# Processing Record 8 of Set 11 | maragogi
# City not found. Skipping...
# Processing Record 9 of Set 11 | diffa
# City not found. Skipping...
# Processing Record 10 of Set 11 | salalah
# City not found. Skipping...
# Processing Record 11 of Set 11 | belyy yar
# Processing Record 12 of Set 11 | sorvag
# City not found. Skipping...
# Processing Record 13 of Set 11 | phayakkhaphum phisai
# Processing Record 14 of Set 11 | cidreira
# Processing Record 15 of Set 11 | southbridge
# Processing Record 16 of Set 11 | westport
# Processing Record 17 of Set 11 | coquimbo
# City not found. Skipping...
# Processing Record 18 of Set 11 | alugan
# City not found. Skipping...
# Processing Record 19 of Set 11 | hovd
# City not found. Skipping...
# Processing Record 20 of Set 11 | trofors
# City not found. Skipping...
# Processing Record 21 of Set 11 | beidao
# City not found. Skipping...
# Processing Record 22 of Set 11 | porto santo
# City not found. Skipping...
# Processing Record 23 of Set 11 | yen bai
# City not found. Skipping...
# Processing Record 24 of Set 11 | havoysund
# Processing Record 25 of Set 11 | katsuura
# Processing Record 26 of Set 11 | carballo
# Processing Record 27 of Set 11 | abalak
# Processing Record 28 of Set 11 | binga
# Processing Record 29 of Set 11 | muisne
# Processing Record 30 of Set 11 | saint-francois
# Processing Record 31 of Set 11 | san juan del sur
# Processing Record 32 of Set 11 | ust-uda
# Processing Record 33 of Set 11 | rawlins
# Processing Record 34 of Set 11 | sokoto
# Processing Record 35 of Set 11 | vangaindrano
# Processing Record 36 of Set 11 | xuzhou
# Processing Record 37 of Set 11 | farsund
# Processing Record 38 of Set 11 | tongliao
# Processing Record 39 of Set 11 | hambantota
# Processing Record 40 of Set 11 | owando
# Processing Record 41 of Set 11 | mangan
# Processing Record 42 of Set 11 | ondjiva
# Processing Record 43 of Set 11 | atherton
# Processing Record 44 of Set 11 | mizdah
# Processing Record 45 of Set 11 | san andres
# Processing Record 46 of Set 11 | havre
# Processing Record 47 of Set 11 | ketchikan
# Processing Record 48 of Set 11 | acarau
# City not found. Skipping...
# Processing Record 49 of Set 11 | spassk
# Processing Record 0 of Set 12 | shirvan
# City not found. Skipping...
# Processing Record 1 of Set 12 | pindwara
# Processing Record 2 of Set 12 | makung
# City not found. Skipping...
# Processing Record 3 of Set 12 | tankhoy
# Processing Record 4 of Set 12 | artyk
# City not found. Skipping...
# Processing Record 5 of Set 12 | lasa
# Processing Record 6 of Set 12 | moron
# Processing Record 7 of Set 12 | samarai
# Processing Record 8 of Set 12 | urengoy
# Processing Record 9 of Set 12 | lhuntshi
# City not found. Skipping...
# Processing Record 10 of Set 12 | fulitun
# City not found. Skipping...
# Processing Record 11 of Set 12 | coahuayana
# Processing Record 12 of Set 12 | pine castle
# Processing Record 13 of Set 12 | talaya
# Processing Record 14 of Set 12 | macaboboni
# City not found. Skipping...
# Processing Record 15 of Set 12 | zhoucun
# Processing Record 16 of Set 12 | coolum beach
# Processing Record 17 of Set 12 | gambiran
# Processing Record 18 of Set 12 | kodinsk
# Processing Record 19 of Set 12 | moa
# Processing Record 20 of Set 12 | leningradskiy
# Processing Record 21 of Set 12 | bur gabo
# City not found. Skipping...
# Processing Record 22 of Set 12 | ikwiriri
# Processing Record 23 of Set 12 | tahe
# Processing Record 24 of Set 12 | husavik
# Processing Record 25 of Set 12 | kemerovo
# Processing Record 26 of Set 12 | balkanabat
# Processing Record 27 of Set 12 | karauzyak
# City not found. Skipping...
# Processing Record 28 of Set 12 | lalgudi
# Processing Record 29 of Set 12 | svetlogorsk
# Processing Record 30 of Set 12 | kargasok
# Processing Record 31 of Set 12 | pitimbu
# Processing Record 32 of Set 12 | galle
# Processing Record 33 of Set 12 | moroni
# Processing Record 34 of Set 12 | teshie
# Processing Record 35 of Set 12 | raymond
# Processing Record 36 of Set 12 | ostrovnoy
# Processing Record 37 of Set 12 | tres arroyos
# Processing Record 38 of Set 12 | sao raimundo nonato
# City not found. Skipping...
# Processing Record 39 of Set 12 | svetlyy
# City not found. Skipping...
# Processing Record 40 of Set 12 | wahiawa
# Processing Record 41 of Set 12 | ekhabi
# Processing Record 42 of Set 12 | avera
# Processing Record 43 of Set 12 | hervey bay
# Processing Record 44 of Set 12 | vao
# Processing Record 45 of Set 12 | vuktyl
# Processing Record 46 of Set 12 | rawson
# Processing Record 47 of Set 12 | oktyabrskoye
# Processing Record 48 of Set 12 | gizo
# Processing Record 49 of Set 12 | karakendzha
# City not found. Skipping...
# Processing Record 0 of Set 13 | ulladulla
# Processing Record 1 of Set 13 | solano
# Processing Record 2 of Set 13 | guspini
# Processing Record 3 of Set 13 | pochutla
# Processing Record 4 of Set 13 | san alberto
# Processing Record 5 of Set 13 | khorixas
# Processing Record 6 of Set 13 | luanda
# Processing Record 7 of Set 13 | arinos
# Processing Record 8 of Set 13 | suao
# City not found. Skipping...
# Processing Record 9 of Set 13 | mutis
# Processing Record 10 of Set 13 | ahipara
# Processing Record 11 of Set 13 | otavi
# Processing Record 12 of Set 13 | limoges
# Processing Record 13 of Set 13 | belmonte
# Processing Record 14 of Set 13 | ambon
# Processing Record 15 of Set 13 | riviere-au-renard
# Processing Record 16 of Set 13 | riyadh
# Processing Record 17 of Set 13 | ambilobe
# Processing Record 18 of Set 13 | whitianga
# Processing Record 19 of Set 13 | bonavista
# Processing Record 20 of Set 13 | shelkovskaya
# Processing Record 21 of Set 13 | gorontalo
# Processing Record 22 of Set 13 | balimo
# City not found. Skipping...
# Processing Record 23 of Set 13 | sur
# Processing Record 24 of Set 13 | porto novo
# Processing Record 25 of Set 13 | esperance
# Processing Record 26 of Set 13 | novyy urengoy
# Processing Record 27 of Set 13 | elizabeth city
# Processing Record 28 of Set 13 | bud
# Processing Record 29 of Set 13 | yerbogachen
# Processing Record 30 of Set 13 | san isidro
# Processing Record 31 of Set 13 | madison
# Processing Record 32 of Set 13 | monastirakion
# Processing Record 33 of Set 13 | ulaangom
# Processing Record 34 of Set 13 | cururupu
# Processing Record 35 of Set 13 | dembi dolo
# Processing Record 36 of Set 13 | lorengau
# Processing Record 37 of Set 13 | cienfuegos

# %%
# Convert array of JSONs into Pandas DataFrame
city_data_pd = pd.DataFrame(city_data)

# Extract relevant fields from the data frame
lats = city_data_pd["Lat"]
max_temps = city_data_pd["Max Temp"]
humidity = city_data_pd["Humidity"]
cloudiness = city_data_pd["Cloudiness"]
wind_speed = city_data_pd["Wind Speed"]

# Export the City_Data into a csv
#city_data_pd.to_csv(output_data_file, index_label="City_ID")

# Show Record Count
city_data_pd.count()
# Out:
# City          551
# Cloudiness    551
# Country       551
# Date          551
# Humidity      551
# Lat           551
# Lng           551
# Max Temp      551
# Wind Speed    551
# dtype: int64

# %%
# Display the City Data Frame
city_data_pd.head()
# Out:
#           City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0    saskylakh           8      RU  1547081574         0  71.97  114.09
# 1      itarema          92      BR  1547081526        97  -2.92  -39.92
# 2       faanui          76      PF  1547081388       100 -16.48 -151.75
# 3  antofagasta          20      CL  1547078400        77 -23.65  -70.40
# 4        tiksi          32      RU  1547081537        77  71.64  128.87
#
#    Max Temp  Wind Speed
# 0    -43.98        5.61
# 1     74.33        3.94
# 2     80.85       14.00
# 3     66.20        9.17
# 4    -38.22        4.05

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(lats, 
            max_temps,
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature (%s)" % time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
#plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(lats, 
            humidity,
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity (%s)" % time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
#plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(lats, 
            cloudiness,
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness (%s)" % time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
#plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(lats, 
            wind_speed,
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed (%s)" % time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
#plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()
